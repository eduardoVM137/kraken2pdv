-- %% [markdown]
-- # [PDVKraken_2]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PDVKraken_2]    Script Date: 27/03/2024 01:13:35 a. m. ******/
CREATE DATABASE [PDVKraken_2]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PDVKraken_2', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\PDVKraken_2.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PDVKraken_2_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\PDVKraken_2_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [PDVKraken_2] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PDVKraken_2].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PDVKraken_2] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PDVKraken_2] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PDVKraken_2] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PDVKraken_2] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PDVKraken_2] SET ARITHABORT OFF 
GO
ALTER DATABASE [PDVKraken_2] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [PDVKraken_2] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PDVKraken_2] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PDVKraken_2] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PDVKraken_2] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PDVKraken_2] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PDVKraken_2] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PDVKraken_2] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PDVKraken_2] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PDVKraken_2] SET  DISABLE_BROKER 
GO
ALTER DATABASE [PDVKraken_2] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PDVKraken_2] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PDVKraken_2] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PDVKraken_2] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PDVKraken_2] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PDVKraken_2] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PDVKraken_2] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PDVKraken_2] SET RECOVERY FULL 
GO
ALTER DATABASE [PDVKraken_2] SET  MULTI_USER 
GO
ALTER DATABASE [PDVKraken_2] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PDVKraken_2] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PDVKraken_2] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PDVKraken_2] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PDVKraken_2] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PDVKraken_2] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'PDVKraken_2', N'ON'
GO
ALTER DATABASE [PDVKraken_2] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[categoria]

-- %%
USE [PDVKraken_2]
GO

-- %%
/****** Object:  Table [dbo].[categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[categoria](
	[idcategoria] [int] IDENTITY(1,1) NOT NULL,
	[idstate] [int] NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [varchar](200) NULL,
 CONSTRAINT [PK_Categoria] PRIMARY KEY CLUSTERED 
(
	[idcategoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[cliente]

-- %%
/****** Object:  Table [dbo].[cliente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cliente](
	[idcliente] [int] IDENTITY(1,1) NOT NULL,
	[idstate] [int] NULL,
	[codigo_cliente] [varchar](50) NULL,
	[nombre] [varchar](150) NULL,
	[apellidos] [varchar](200) NULL,
	[foto] [image] NULL,
	[direccion] [varchar](150) NULL,
	[telefono] [varchar](50) NULL,
	[correo] [varchar](150) NULL,
	[fecha_nacimiento] [date] NULL,
	[comentarios] [varchar](250) NULL,
 CONSTRAINT [PK_cliente] PRIMARY KEY CLUSTERED 
(
	[idcliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[componente]

-- %%
/****** Object:  Table [dbo].[componente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[componente](
	[idcomponente] [int] IDENTITY(1,1) NOT NULL,
	[idproducto] [int] NOT NULL,
	[idproducto_item] [int] NOT NULL,
	[cantidad] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_dtpaquete] PRIMARY KEY CLUSTERED 
(
	[idcomponente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[corte_caja]

-- %%
/****** Object:  Table [dbo].[corte_caja]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[corte_caja](
	[idcorte_caja] [int] IDENTITY(1,1) NOT NULL,
	[idempleado_usuario] [int] NOT NULL,
	[fecha_hora_inicio] [datetime] NOT NULL,
	[fecha_hora_fin] [datetime] NOT NULL,
	[fondo_inicial] [decimal](18, 2) NOT NULL,
	[total_retiros] [decimal](18, 2) NOT NULL,
	[total_ventas] [decimal](18, 2) NOT NULL,
	[total_entregado] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_corte_caja] PRIMARY KEY CLUSTERED 
(
	[idcorte_caja] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[detalle_ingreso]

-- %%
/****** Object:  Table [dbo].[detalle_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[detalle_ingreso](
	[iddetalle_ingreso] [int] IDENTITY(1,1) NOT NULL,
	[idingreso] [int] NOT NULL,
	[idproducto] [int] NOT NULL,
	[idstate] [int] NULL,
	[cantidad] [int] NOT NULL,
	[precio_costo] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_dtingreso] PRIMARY KEY CLUSTERED 
(
	[iddetalle_ingreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[detalle_state]

-- %%
/****** Object:  Table [dbo].[detalle_state]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[detalle_state](
	[idetalle_state] [int] IDENTITY(1,1) NOT NULL,
	[idstate] [int] NOT NULL,
	[idempleado_usuario] [int] NOT NULL,
	[fecha] [datetime] NOT NULL,
	[estado] [varchar](100) NOT NULL,
 CONSTRAINT [PK_detalle_state] PRIMARY KEY CLUSTERED 
(
	[idetalle_state] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[detalle_venta]

-- %%
/****** Object:  Table [dbo].[detalle_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[detalle_venta](
	[iddetalle_venta] [int] IDENTITY(1,1) NOT NULL,
	[idventa] [int] NULL,
	[idempleado] [int] NULL,
	[idproducto] [int] NULL,
	[cantidad] [decimal](18, 2) NULL,
	[precio] [decimal](18, 2) NULL,
	[descuento] [decimal](18, 2) NULL,
	[subtotal] [decimal](18, 2) NULL,
 CONSTRAINT [PK_detalle_venta] PRIMARY KEY CLUSTERED 
(
	[iddetalle_venta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[empleado]

-- %%
/****** Object:  Table [dbo].[empleado]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[empleado](
	[idempleado] [int] IDENTITY(1,1) NOT NULL,
	[codigo_empleado] [varchar](50) NOT NULL,
	[nombre] [varchar](150) NOT NULL,
	[apellidos] [varchar](200) NULL,
	[foto] [image] NULL,
	[direccion] [varchar](50) NULL,
	[telefono] [varchar](50) NULL,
	[correo] [varchar](150) NULL,
	[fecha_nacimiento] [date] NULL,
	[comentarios] [varchar](250) NULL,
	[idstate] [int] NULL,
 CONSTRAINT [PK_empleado] PRIMARY KEY CLUSTERED 
(
	[idempleado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ingreso]

-- %%
/****** Object:  Table [dbo].[ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ingreso](
	[idingreso] [int] IDENTITY(1,1) NOT NULL,
	[idempleado] [int] NOT NULL,
	[idproveedor] [int] NOT NULL,
	[idstate] [int] NULL,
	[fecha] [datetime] NOT NULL,
	[metodo_pago] [varchar](50) NULL,
	[comprobante] [varchar](150) NULL,
	[iva] [decimal](18, 2) NULL,
	[total] [decimal](18, 2) NOT NULL,
	[pagado] [varchar](50) NULL,
 CONSTRAINT [PK_ingreso] PRIMARY KEY CLUSTERED 
(
	[idingreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[inventario]

-- %%
/****** Object:  Table [dbo].[inventario]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[inventario](
	[idinventario] [int] IDENTITY(1,1) NOT NULL,
	[idproducto] [int] NOT NULL,
	[stock_actual] [decimal](18, 2) NULL,
	[stock_minimo] [decimal](18, 2) NULL,
 CONSTRAINT [PK_inventario] PRIMARY KEY CLUSTERED 
(
	[idinventario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[productos]

-- %%
/****** Object:  Table [dbo].[productos]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[productos](
	[idproducto] [int] IDENTITY(1,1) NOT NULL,
	[idcategoria] [int] NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[precio_costo] [decimal](18, 2) NULL,
	[precio_venta] [decimal](18, 2) NOT NULL,
	[tipo] [varchar](50) NULL,
	[idstate] [int] NULL,
	[presentacion] [varchar](50) NULL,
	[ubicacion] [varchar](50) NULL,
	[foto] [varchar](50) NULL,
	[codigo_barras] [varchar](50) NULL,
	[codigo_propio] [varchar](50) NULL,
 CONSTRAINT [PK_productos] PRIMARY KEY CLUSTERED 
(
	[idproducto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[proveedor]

-- %%
/****** Object:  Table [dbo].[proveedor]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[proveedor](
	[idproveedor] [int] IDENTITY(1,1) NOT NULL,
	[idstate] [int] NULL,
	[codigo_proveedor] [varchar](100) NULL,
	[nombre] [varchar](250) NOT NULL,
	[rfc] [varchar](50) NULL,
	[direccion] [varchar](50) NULL,
	[telefono] [varchar](20) NULL,
	[correo] [varchar](150) NULL,
	[comentarios] [varchar](250) NULL,
	[foto] [image] NULL,
 CONSTRAINT [PK_proveedor] PRIMARY KEY CLUSTERED 
(
	[idproveedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[retiro]

-- %%
/****** Object:  Table [dbo].[retiro]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[retiro](
	[idretiro] [int] IDENTITY(1,1) NOT NULL,
	[idempleado_usuario] [int] NOT NULL,
	[idcorte_caja] [int] NOT NULL,
	[fecha_hora] [datetime] NOT NULL,
	[monto] [decimal](18, 2) NOT NULL,
	[motivo] [varchar](250) NULL,
 CONSTRAINT [PK_retiro] PRIMARY KEY CLUSTERED 
(
	[idretiro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[state]

-- %%
/****** Object:  Table [dbo].[state]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[state](
	[idstate] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_state] PRIMARY KEY CLUSTERED 
(
	[idstate] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sub_categoria]

-- %%
/****** Object:  Table [dbo].[sub_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sub_categoria](
	[idsub_categoria] [int] IDENTITY(1,1) NOT NULL,
	[idcategoria] [int] NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [varchar](200) NULL,
 CONSTRAINT [PK_SubCategoria] PRIMARY KEY CLUSTERED 
(
	[idsub_categoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[venta]

-- %%
/****** Object:  Table [dbo].[venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[venta](
	[idventa] [int] IDENTITY(1,1) NOT NULL,
	[idempleado_usuario] [int] NULL,
	[idcliente] [int] NULL,
	[idstate] [int] NULL,
	[fecha] [datetime] NULL,
	[metodo_pago] [varchar](50) NULL,
	[comprobante] [varchar](50) NULL,
	[iva] [decimal](18, 2) NULL,
	[total] [decimal](18, 2) NULL,
	[pagado] [varchar](50) NULL,
	[comentarios] [varchar](150) NULL,
 CONSTRAINT [PK_venta] PRIMARY KEY CLUSTERED 
(
	[idventa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_cliente_state]

-- %%
ALTER TABLE [dbo].[cliente]  WITH CHECK ADD  CONSTRAINT [FK_cliente_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[cliente] CHECK CONSTRAINT [FK_cliente_state]
GO

-- %% [markdown]
-- # [FK_componente_productos]

-- %%
ALTER TABLE [dbo].[componente]  WITH CHECK ADD  CONSTRAINT [FK_componente_productos] FOREIGN KEY([idproducto])
REFERENCES [dbo].[productos] ([idproducto])
GO
ALTER TABLE [dbo].[componente] CHECK CONSTRAINT [FK_componente_productos]
GO

-- %% [markdown]
-- # [FK_componente_productos1]

-- %%
ALTER TABLE [dbo].[componente]  WITH CHECK ADD  CONSTRAINT [FK_componente_productos1] FOREIGN KEY([idproducto_item])
REFERENCES [dbo].[productos] ([idproducto])
GO
ALTER TABLE [dbo].[componente] CHECK CONSTRAINT [FK_componente_productos1]
GO

-- %% [markdown]
-- # [FK_corte_caja_empleado]

-- %%
ALTER TABLE [dbo].[corte_caja]  WITH CHECK ADD  CONSTRAINT [FK_corte_caja_empleado] FOREIGN KEY([idempleado_usuario])
REFERENCES [dbo].[empleado] ([idempleado])
GO
ALTER TABLE [dbo].[corte_caja] CHECK CONSTRAINT [FK_corte_caja_empleado]
GO

-- %% [markdown]
-- # [FK_dtingreso_ingreso]

-- %%
ALTER TABLE [dbo].[detalle_ingreso]  WITH CHECK ADD  CONSTRAINT [FK_dtingreso_ingreso] FOREIGN KEY([idingreso])
REFERENCES [dbo].[ingreso] ([idingreso])
GO
ALTER TABLE [dbo].[detalle_ingreso] CHECK CONSTRAINT [FK_dtingreso_ingreso]
GO

-- %% [markdown]
-- # [FK_dtingreso_productos]

-- %%
ALTER TABLE [dbo].[detalle_ingreso]  WITH CHECK ADD  CONSTRAINT [FK_dtingreso_productos] FOREIGN KEY([idproducto])
REFERENCES [dbo].[productos] ([idproducto])
GO
ALTER TABLE [dbo].[detalle_ingreso] CHECK CONSTRAINT [FK_dtingreso_productos]
GO

-- %% [markdown]
-- # [FK_detalle_state_state]

-- %%
ALTER TABLE [dbo].[detalle_state]  WITH CHECK ADD  CONSTRAINT [FK_detalle_state_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[detalle_state] CHECK CONSTRAINT [FK_detalle_state_state]
GO

-- %% [markdown]
-- # [FK_detalle_venta_empleado]

-- %%
ALTER TABLE [dbo].[detalle_venta]  WITH CHECK ADD  CONSTRAINT [FK_detalle_venta_empleado] FOREIGN KEY([idempleado])
REFERENCES [dbo].[empleado] ([idempleado])
GO
ALTER TABLE [dbo].[detalle_venta] CHECK CONSTRAINT [FK_detalle_venta_empleado]
GO

-- %% [markdown]
-- # [FK_detalle_venta_productos]

-- %%
ALTER TABLE [dbo].[detalle_venta]  WITH CHECK ADD  CONSTRAINT [FK_detalle_venta_productos] FOREIGN KEY([idproducto])
REFERENCES [dbo].[productos] ([idproducto])
GO
ALTER TABLE [dbo].[detalle_venta] CHECK CONSTRAINT [FK_detalle_venta_productos]
GO

-- %% [markdown]
-- # [FK_detalle_venta_venta]

-- %%
ALTER TABLE [dbo].[detalle_venta]  WITH CHECK ADD  CONSTRAINT [FK_detalle_venta_venta] FOREIGN KEY([idventa])
REFERENCES [dbo].[venta] ([idventa])
GO
ALTER TABLE [dbo].[detalle_venta] CHECK CONSTRAINT [FK_detalle_venta_venta]
GO

-- %% [markdown]
-- # [FK_empleado_state]

-- %%
ALTER TABLE [dbo].[empleado]  WITH CHECK ADD  CONSTRAINT [FK_empleado_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[empleado] CHECK CONSTRAINT [FK_empleado_state]
GO

-- %% [markdown]
-- # [FK_ingreso_empleado]

-- %%
ALTER TABLE [dbo].[ingreso]  WITH CHECK ADD  CONSTRAINT [FK_ingreso_empleado] FOREIGN KEY([idempleado])
REFERENCES [dbo].[empleado] ([idempleado])
GO
ALTER TABLE [dbo].[ingreso] CHECK CONSTRAINT [FK_ingreso_empleado]
GO

-- %% [markdown]
-- # [FK_ingreso_proveedor]

-- %%
ALTER TABLE [dbo].[ingreso]  WITH CHECK ADD  CONSTRAINT [FK_ingreso_proveedor] FOREIGN KEY([idproveedor])
REFERENCES [dbo].[proveedor] ([idproveedor])
GO
ALTER TABLE [dbo].[ingreso] CHECK CONSTRAINT [FK_ingreso_proveedor]
GO

-- %% [markdown]
-- # [FK_ingreso_state]

-- %%
ALTER TABLE [dbo].[ingreso]  WITH CHECK ADD  CONSTRAINT [FK_ingreso_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[ingreso] CHECK CONSTRAINT [FK_ingreso_state]
GO

-- %% [markdown]
-- # [FK_inventario_productos]

-- %%
ALTER TABLE [dbo].[inventario]  WITH CHECK ADD  CONSTRAINT [FK_inventario_productos] FOREIGN KEY([idproducto])
REFERENCES [dbo].[productos] ([idproducto])
GO
ALTER TABLE [dbo].[inventario] CHECK CONSTRAINT [FK_inventario_productos]
GO

-- %% [markdown]
-- # [FK_productos_Categoria]

-- %%
ALTER TABLE [dbo].[productos]  WITH CHECK ADD  CONSTRAINT [FK_productos_Categoria] FOREIGN KEY([idcategoria])
REFERENCES [dbo].[categoria] ([idcategoria])
GO
ALTER TABLE [dbo].[productos] CHECK CONSTRAINT [FK_productos_Categoria]
GO

-- %% [markdown]
-- # [FK_productos_state]

-- %%
ALTER TABLE [dbo].[productos]  WITH CHECK ADD  CONSTRAINT [FK_productos_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[productos] CHECK CONSTRAINT [FK_productos_state]
GO

-- %% [markdown]
-- # [FK_proveedor_state]

-- %%
ALTER TABLE [dbo].[proveedor]  WITH CHECK ADD  CONSTRAINT [FK_proveedor_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[proveedor] CHECK CONSTRAINT [FK_proveedor_state]
GO

-- %% [markdown]
-- # [FK_retiro_corte_caja]

-- %%
ALTER TABLE [dbo].[retiro]  WITH CHECK ADD  CONSTRAINT [FK_retiro_corte_caja] FOREIGN KEY([idcorte_caja])
REFERENCES [dbo].[corte_caja] ([idcorte_caja])
GO
ALTER TABLE [dbo].[retiro] CHECK CONSTRAINT [FK_retiro_corte_caja]
GO

-- %% [markdown]
-- # [FK_SubCategoria_Categoria1]

-- %%
ALTER TABLE [dbo].[sub_categoria]  WITH CHECK ADD  CONSTRAINT [FK_SubCategoria_Categoria1] FOREIGN KEY([idcategoria])
REFERENCES [dbo].[categoria] ([idcategoria])
GO
ALTER TABLE [dbo].[sub_categoria] CHECK CONSTRAINT [FK_SubCategoria_Categoria1]
GO

-- %% [markdown]
-- # [FK_venta_cliente]

-- %%
ALTER TABLE [dbo].[venta]  WITH CHECK ADD  CONSTRAINT [FK_venta_cliente] FOREIGN KEY([idcliente])
REFERENCES [dbo].[cliente] ([idcliente])
GO
ALTER TABLE [dbo].[venta] CHECK CONSTRAINT [FK_venta_cliente]
GO

-- %% [markdown]
-- # [FK_venta_empleado]

-- %%
ALTER TABLE [dbo].[venta]  WITH CHECK ADD  CONSTRAINT [FK_venta_empleado] FOREIGN KEY([idempleado_usuario])
REFERENCES [dbo].[empleado] ([idempleado])
GO
ALTER TABLE [dbo].[venta] CHECK CONSTRAINT [FK_venta_empleado]
GO

-- %% [markdown]
-- # [FK_venta_state]

-- %%
ALTER TABLE [dbo].[venta]  WITH CHECK ADD  CONSTRAINT [FK_venta_state] FOREIGN KEY([idstate])
REFERENCES [dbo].[state] ([idstate])
GO
ALTER TABLE [dbo].[venta] CHECK CONSTRAINT [FK_venta_state]
GO

-- %% [markdown]
-- # [dbo].[spdetalle_state_insertar]

-- %%
/****** Object:  StoredProcedure [dbo].[spdetalle_state_insertar]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[spdetalle_state_insertar]--se llama en el backend para insertar un nuevo valor
    @idempleado_usuario int,
	@idstate int,
	@estado varchar(100)
AS
insert into detalle_state (idempleado_usuario,idstate,fecha,estado)
	values (@idempleado_usuario,@idstate,getdate(),@estado)
GO

-- %% [markdown]
-- # [dbo].[speditar_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_categoria] --enviar el anulado u otro estado
    @idcategoria int,
    @nombre varchar(100),
    @descripcion varchar(200)
AS
UPDATE categoria
SET nombre = @nombre,
    descripcion = @descripcion
WHERE idcategoria = @idcategoria
GO

-- %% [markdown]
-- # [dbo].[speditar_cliente]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_cliente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_cliente]--enviar el anulado u otro estado
    @idcliente int,
    @idstate int,
    @codigocliente varchar(50),
    @nombre varchar(150),
    @apellidos varchar(200),
    @foto image,
    @direccion varchar(150),
    @telefono varchar(50),
    @correo varchar(150),
    @fecha_nacimiento date,
    @comentarios varchar(250)
AS
begin
UPDATE cliente
SET idstate = @idstate,
    codigo_cliente = @codigocliente,
    nombre = @nombre,
    apellidos = @apellidos,
    foto = @foto,
    direccion = @direccion,
    telefono = @telefono,
    correo = @correo,
    fecha_nacimiento = @fecha_nacimiento,
    comentarios = @comentarios
WHERE idcliente = @idcliente
end
GO

-- %% [markdown]
-- # [dbo].[speditar_componente]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_componente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_componente]
    @idcomponente int,
    @idproducto int,
    @idproducto_item int,
    @cantidad decimal(18, 2)
AS
UPDATE componente
SET idproducto = @idproducto,
    idproducto_item = @idproducto_item,
    cantidad = @cantidad
WHERE idcomponente = @idcomponente
GO

-- %% [markdown]
-- # [dbo].[speditar_corte_caja]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_corte_caja]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_corte_caja]
    @idcorte_caja int,
    @idempleado_usuario int,
    @fecha_hora_in datetime,
    @fecha_hora_fin datetime,
    @fondo_inicial decimal(18, 2),
    @total_retiros decimal(18, 2),
    @total_ventas decimal(18, 2),
    @total_entregado decimal(18, 2)
AS
UPDATE corte_caja
SET idempleado_usuario = @idempleado_usuario,
    fecha_hora_inicio = @fecha_hora_in,
    fecha_hora_fin = @fecha_hora_fin,
    fondo_inicial = @fondo_inicial,
    total_retiros = @total_retiros,
    total_ventas = @total_ventas,
    total_entregado = @total_entregado
WHERE idcorte_caja = @idcorte_caja
GO

-- %% [markdown]
-- # [dbo].[speditar_detalle_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_detalle_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_detalle_ingreso]
    @iddetalle_ingreso int,
	@idingreso int,
    @idproducto int,
    @idstate int,
    @cantidad int,
    @precio_costo decimal(18, 2)
AS
UPDATE detalle_ingreso
SET idingreso = @idingreso,
    idproducto = @idproducto,
	idstate=@idstate,
    cantidad = @cantidad,
    precio_costo = @precio_costo
WHERE iddetalle_ingreso = @iddetalle_ingreso
GO

-- %% [markdown]
-- # [dbo].[speditar_detalle_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_detalle_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_detalle_venta]
    @iddetalle_venta int,
    @idventa int,
	@idempleado int,
    @idproducto int,
    @cantidad int,
    @precio decimal(18, 2),
    @descuento decimal(18, 2),
    @subtotal decimal(18, 2)
AS
UPDATE detalle_venta
SET idventa = @idventa,
    idproducto = @idproducto,
    idempleado = @idempleado,
    cantidad = @cantidad,
    precio = @precio,
    descuento = @descuento,
    subtotal = @subtotal
WHERE iddetalle_venta = @iddetalle_venta
GO

-- %% [markdown]
-- # [dbo].[speditar_empleado]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_empleado]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_empleado]--enviar el anulado u otro estado
    @idempleado int,
    @codigo_empleado varchar(50),
    @nombre varchar(150),
    @apellidos varchar(200),
    @foto image,
    @direccion varchar(50),
    @telefono varchar(50),
    @correo varchar(150),
    @fecha_nacimiento date,
    @comentarios varchar(250),
    @idstate int
AS

UPDATE empleado
SET codigo_empleado = @codigo_empleado,
    nombre = @nombre,
    apellidos = @apellidos,
    foto = @foto,
    direccion = @direccion,
    telefono = @telefono,
    correo = @correo,
    fecha_nacimiento = @fecha_nacimiento,
    comentarios = @comentarios,
    idstate = @idstate
WHERE idempleado = @idempleado
GO

-- %% [markdown]
-- # [dbo].[speditar_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_ingreso] --enviar el anulado u otro estado
    @idingreso int,
    @idempleado int,
    @idproveedor int,
    @idstate int,
    @fecha datetime,
    @metodo_pago varchar(50),
    @comprobante varchar(150),
    @iva decimal(18, 2),
    @total decimal(18, 2),
    @pagado varchar(50)
AS
UPDATE ingreso
SET idempleado = @idempleado,
    idproveedor = @idproveedor,
    idstate = @idstate,
    fecha = @fecha,
    metodo_pago = @metodo_pago,
    comprobante = @comprobante,
    iva = @iva,
    total = @total,
    pagado = @pagado
WHERE idingreso = @idingreso
GO

-- %% [markdown]
-- # [dbo].[speditar_inventario]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_inventario]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_inventario]
    @idinventario int,
    @idproducto int,
    @stock_actual decimal(18, 2),
    @stock_minimo decimal(18, 2)
AS
UPDATE inventario
SET idproducto = @idproducto,
    stock_actual = @stock_actual,
    stock_minimo = @stock_minimo
WHERE idinventario = @idinventario
GO

-- %% [markdown]
-- # [dbo].[speditar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_producto]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_producto] --enviar el anulado u otro estado
    @idproducto int,
    @idcategoria int,
    @nombre varchar(50),
    @precio_costo decimal(18, 2),
    @precio_venta decimal(18, 2),
    @tipo varchar(50),
    @idstate int,
    @presentacion varchar(50),
    @ubicacion varchar(50),
    @foto varbinary(MAX),
    @codigo_barras varchar(50),
    @codigo_propio varchar(50)
AS
UPDATE productos
SET idcategoria = @idcategoria,
    nombre = @nombre,
    precio_costo = @precio_costo,
    precio_venta = @precio_venta,
    tipo = @tipo,
    idstate = @idstate,
    presentacion = @presentacion,
    ubicacion = @ubicacion,
    foto = @foto,
    codigo_barras = @codigo_barras,
    codigo_propio = @codigo_propio
WHERE idproducto = @idproducto
GO

-- %% [markdown]
-- # [dbo].[speditar_proveedor]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_proveedor]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_proveedor] --enviar el anulado u otro estado
    @idproveedor int,
    @idstate int,
    @codigo_proveedor varchar(100),
    @nombre varchar(250),
    @rfc varchar(50),
    @direccion varchar(50),
    @telefono varchar(20),
    @correo varchar(150),
    @comentarios varchar(250),
    @foto image
AS
UPDATE proveedor
SET idstate = @idstate,
    codigo_proveedor = @codigo_proveedor,
    nombre = @nombre,
    rfc = @rfc,
    direccion = @direccion,
    telefono = @telefono,
    correo = @correo,
    comentarios = @comentarios,
    foto = @foto
WHERE idproveedor = @idproveedor
GO

-- %% [markdown]
-- # [dbo].[speditar_retiro]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_retiro]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_retiro]
    @idretiro int,
    @idempleado_usuario int,
    @fecha_hora datetime,
    @monto decimal(18, 2),
    @motivo varchar(250)
AS
UPDATE retiro
SET idempleado_usuario = @idempleado_usuario,
    fecha_hora = @fecha_hora,
    monto = @monto,
    motivo = @motivo
WHERE idretiro = @idretiro
GO

-- %% [markdown]
-- # [dbo].[speditar_sub_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_sub_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_sub_categoria]
    @idsub_categoria int,
    @idcategoria int,
    @nombre varchar(100),
    @descripcion varchar(200)
AS
UPDATE sub_categoria
SET idcategoria = @idcategoria,
    nombre = @nombre,
    descripcion = @descripcion
WHERE idsub_categoria = @idsub_categoria
GO

-- %% [markdown]
-- # [dbo].[speditar_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[speditar_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speditar_venta]--enviar el anulado u otro estado
    @idventa int,
    @idempleado_usuario int,
    @idcliente int,
    @idstate int,
    @fecha datetime,
    @metodo_pago varchar(50),
    @comprobante varchar(50),
    @iva decimal(18, 2),
    @total decimal(18, 2),
    @pagado varchar(50),
    @comentarios varchar(150)
AS
UPDATE venta
SET idempleado_usuario = @idempleado_usuario,
    idcliente = @idcliente,
    idstate = @idstate,
    fecha = @fecha,
    metodo_pago = @metodo_pago,
    comprobante = @comprobante,
    iva = @iva,
    total = @total,
    pagado = @pagado,
    comentarios = @comentarios
WHERE idventa = @idventa
GO

-- %% [markdown]
-- # [dbo].[speliminar_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_categoria]
    @idcategoria int
AS
DELETE FROM categoria
WHERE idcategoria = @idcategoria
GO

-- %% [markdown]
-- # [dbo].[speliminar_cliente]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_cliente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_cliente]
    @idcliente int
AS
DELETE FROM cliente
WHERE idcliente = @idcliente
GO

-- %% [markdown]
-- # [dbo].[speliminar_componente]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_componente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_componente]
    @idcomponente int
AS
DELETE FROM componente
WHERE idcomponente = @idcomponente
GO

-- %% [markdown]
-- # [dbo].[speliminar_corte_caja]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_corte_caja]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_corte_caja]
    @idcorte_caja int
AS
DELETE FROM corte_caja
WHERE idcorte_caja = @idcorte_caja
GO

-- %% [markdown]
-- # [dbo].[speliminar_detalle_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_detalle_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_detalle_ingreso]
    @iddetalle_ingreso int
AS
DELETE FROM detalle_ingreso
WHERE iddetalle_ingreso = @iddetalle_ingreso
GO

-- %% [markdown]
-- # [dbo].[speliminar_detalle_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_detalle_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_detalle_venta]
    @iddetalle_venta int
AS
DELETE FROM detalle_venta
WHERE iddetalle_venta = @iddetalle_venta
GO

-- %% [markdown]
-- # [dbo].[speliminar_empleado]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_empleado]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_empleado]
    @idempleado int
AS
DELETE FROM empleado
WHERE idempleado = @idempleado
GO

-- %% [markdown]
-- # [dbo].[speliminar_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_ingreso]
    @idingreso int
AS
DELETE FROM ingreso
WHERE idingreso = @idingreso
GO

-- %% [markdown]
-- # [dbo].[speliminar_inventario]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_inventario]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_inventario]
    @idinventario int
AS
DELETE FROM inventario
WHERE idinventario = @idinventario
GO

-- %% [markdown]
-- # [dbo].[speliminar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_producto]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_producto]
    @idproducto int
AS
DELETE FROM productos
WHERE idproducto = @idproducto
GO

-- %% [markdown]
-- # [dbo].[speliminar_proveedor]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_proveedor]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_proveedor]--anular
    @idproveedor int
AS
DELETE FROM proveedor
WHERE idproveedor = @idproveedor
GO

-- %% [markdown]
-- # [dbo].[speliminar_retiro]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_retiro]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_retiro]
    @idretiro int
AS
DELETE FROM retiro
WHERE idretiro = @idretiro
GO

-- %% [markdown]
-- # [dbo].[speliminar_sub_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_sub_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_sub_categoria]
    @idsub_categoria int
AS
DELETE FROM sub_categoria
WHERE idsub_categoria = @idsub_categoria
GO

-- %% [markdown]
-- # [dbo].[speliminar_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[speliminar_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[speliminar_venta]
    @idventa int
AS
DELETE FROM venta
WHERE idventa = @idventa
GO

-- %% [markdown]
-- # [dbo].[spinsertar_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'categoria'
CREATE PROC [dbo].[spinsertar_categoria]
	@idempleado_usuario int,
    @nombre varchar(100),
    @descripcion varchar(200)
AS
begin
    DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT

INSERT INTO categoria (idstate, nombre, descripcion)
VALUES (@idstate, @nombre, @descripcion)

	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_cliente]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_cliente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- Procedimientos para la tabla 'cliente'

CREATE PROC [dbo].[spinsertar_cliente]
	@idempleado_usuario int,
    @codigocliente varchar(50),
    @nombre varchar(150),
    @apellidos varchar(200),
    @foto image,
    @direccion varchar(150),
    @telefono varchar(50),
    @correo varchar(150),
    @fecha_nacimiento date,
    @comentarios varchar(250)
AS
BEGIN
    DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
    -- Insertar en cliente con el nuevo idstate
    INSERT INTO cliente (idstate, codigo_cliente, nombre, apellidos, foto, direccion, telefono, correo, fecha_nacimiento, comentarios)
    VALUES ( @idstate, @codigocliente, @nombre, @apellidos, @foto, @direccion, @telefono, @correo, @fecha_nacimiento, @comentarios)
END
GO

-- %% [markdown]
-- # [dbo].[spinsertar_componente]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_componente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'componente'
CREATE PROC [dbo].[spinsertar_componente]
    @idproducto int,
    @idproducto_item int,
    @cantidad decimal(18, 2)
AS
INSERT INTO componente (idproducto, idproducto_item, cantidad)
VALUES (@idproducto, @idproducto_item, @cantidad)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_corte_caja]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_corte_caja]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'corte_caja'
CREATE PROC [dbo].[spinsertar_corte_caja]
    @idempleado_usuario int,
    @fecha_hora_inicio datetime,
    @fecha_hora_fin datetime,
    @fondo_inicial decimal(18, 2),
    @total_retiros decimal(18, 2),
    @total_ventas decimal(18, 2),
    @total_entregado decimal(18, 2)
AS
INSERT INTO corte_caja ( idempleado_usuario, fecha_hora_inicio, fecha_hora_fin, fondo_inicial, total_retiros, total_ventas, total_entregado)
VALUES (@idempleado_usuario, @fecha_hora_inicio, @fecha_hora_fin, @fondo_inicial, @total_retiros, @total_ventas, @total_entregado)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_detalle_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_detalle_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'detalle_ingreso'
CREATE PROC [dbo].[spinsertar_detalle_ingreso]
    @idingreso int,
    @idproducto int,
    @cantidad int,
    @precio_costo decimal(18,0)
AS
INSERT INTO detalle_ingreso ( idingreso, idproducto, cantidad, precio_costo)
VALUES ( @idingreso, @idproducto, @cantidad, @precio_costo)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_detalle_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_detalle_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- Procedimientos para la tabla 'detalle_venta'
CREATE PROC [dbo].[spinsertar_detalle_venta]
  -- va el output  @iddetalle_venta int,
    @idventa int,
    @idempledo int,
    @idproducto int,
    @cantidad int,
    @precio decimal(18, 2),
    @descuento decimal(18,0),
    @subtotal decimal(18, 2)
AS
INSERT INTO detalle_venta ( idventa,idempleado, idproducto, cantidad, precio, descuento, subtotal)
VALUES ( @idventa,@idempledo, @idproducto, @cantidad, @precio, @descuento, @subtotal)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_empleado]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_empleado]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'empleado'
CREATE PROC [dbo].[spinsertar_empleado]
	@idempleado_usuario int,
    @codigo_empleado varchar(50),
    @nombre varchar(150),
    @apellidos varchar(200),
    @foto image,
    @direccion varchar(50),
    @telefono varchar(50),
    @correo varchar(150),
    @fecha_nacimiento date,
    @comentarios varchar(250)
AS
begin
    DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
INSERT INTO empleado ( codigo_empleado, nombre, apellidos, foto, direccion, telefono, correo, fecha_nacimiento, comentarios, idstate)
VALUES ( @codigo_empleado, @nombre, @apellidos, @foto, @direccion, @telefono, @correo, @fecha_nacimiento, @comentarios, @idstate)
	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'ingreso'
CREATE PROC [dbo].[spinsertar_ingreso]
    @idempleado_usuario int,
    @idingreso int,
    @idempleado int,
    @idproveedor int,
    @fecha datetime,
    @metodo_pago varchar(50),
    @comprobante varchar(150),
    @iva decimal(18, 2),
    @total decimal(18, 2),
    @pagado varchar(50)
AS
begin
   DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
INSERT INTO ingreso (idingreso, idempleado, idproveedor, idstate, fecha, metodo_pago, comprobante, iva, total, pagado)
VALUES (@idingreso, @idempleado, @idproveedor, @idstate, @fecha, @metodo_pago, @comprobante, @iva, @total, @pagado)

	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_inventario]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_inventario]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'inventario'
CREATE PROC [dbo].[spinsertar_inventario]
 -- ouput   @idinventario int,
    @idproducto int,
    @stock_actual decimal(18, 2),
    @stock_minimo decimal(18, 2)
AS
INSERT INTO inventario ( idproducto, stock_actual, stock_minimo)
VALUES ( @idproducto, @stock_actual, @stock_minimo)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_producto]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'producto'
CREATE PROC [dbo].[spinsertar_producto]  
@idempleado_usuario int,
    @idcategoria int,
    @nombre varchar(50),
    @precio_costo decimal(18, 2),
    @precio_venta decimal(18, 2),
    @tipo varchar(50),
    @presentacion varchar(50),
    @ubicacion varchar(50),
    @foto varbinary(MAX),
    @codigo_barras varchar(50),
    @codigo_propio varchar(50)
AS
begin 
   DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
INSERT INTO productos ( idcategoria, nombre, precio_costo, precio_venta, tipo, idstate, presentacion, ubicacion, foto, codigo_barras, codigo_propio)
VALUES (@idcategoria, @nombre, @precio_costo, @precio_venta, @tipo, @idstate, @presentacion, @ubicacion, @foto, @codigo_barras, @codigo_propio)

	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_proveedor]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_proveedor]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 -- Procedimientos para la tabla 'proveedor'
CREATE PROC [dbo].[spinsertar_proveedor]
    @idempleado_usuario int,
    @codigo_proveedor varchar(100),
    @nombre varchar(250),
    @rfc varchar(50),
    @direccion varchar(50),
    @telefono varchar(20),
    @correo varchar(150),
    @comentarios varchar(250),
    @foto image
AS
begin
   DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
INSERT INTO proveedor ( idstate, codigo_proveedor, nombre, rfc, direccion, telefono, correo, comentarios, foto)
VALUES (@idstate, @codigo_proveedor, @nombre, @rfc, @direccion, @telefono, @correo, @comentarios, @foto)
	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_retiro]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_retiro]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'retiro'
CREATE PROC [dbo].[spinsertar_retiro]
    @idempleado_usuario int,
    @idcorte_caja int,
    @fecha_hora datetime,
    @monto decimal(18, 2),
    @motivo varchar(250)
AS
INSERT INTO retiro  (idempleado_usuario, idcorte_caja, fecha_hora, monto, motivo)
VALUES ( @idempleado_usuario, @idcorte_caja, @fecha_hora, @monto, @motivo)
GO

-- %% [markdown]
-- # [dbo].[spinsertar_sub_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_sub_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'sub_categoria'
CREATE PROC [dbo].[spinsertar_sub_categoria]
	@idempleado_usuario int,
    @idsub_categoria int,
    @idcategoria int,
    @nombre varchar(100),
    @descripcion varchar(200)
AS
begin
    DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'

INSERT INTO sub_categoria (idsub_categoria, idcategoria, nombre, descripcion)
VALUES (@idsub_categoria, @idcategoria, @nombre, @descripcion)
end
GO

-- %% [markdown]
-- # [dbo].[spinsertar_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[spinsertar_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'venta'
CREATE PROC [dbo].[spinsertar_venta] 
    @idempleado_usuario int,
    @idcliente int,
	@fecha datetime,
    @metodo_pago varchar(50),
    @comprobante varchar(50),
    @iva decimal(18, 2),
    @total decimal(18, 2),
    @pagado varchar(50),
    @comentarios varchar(150)
AS
begin 
   DECLARE @idstate int
    -- Llamar al procedimiento para insertar state y obtener el idstate generado
    EXEC spstate_insertar_nuevo @idstate OUTPUT
INSERT INTO venta ( idempleado_usuario, idcliente, idstate, fecha, metodo_pago, comprobante, iva, total, pagado, comentarios)
VALUES ( @idempleado_usuario, @idcliente, @idstate, @fecha, @metodo_pago, @comprobante, @iva, @total, @pagado, @comentarios)

	exec spdetalle_state_insertar @idempleado_usuario,@idstate,'Activo'
end
GO

-- %% [markdown]
-- # [dbo].[spmostrar_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROC [dbo].[spmostrar_categoria]
AS
SELECT * FROM categoria
ORDER BY idcategoria DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_cliente]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_cliente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROC [dbo].[spmostrar_cliente]
AS
SELECT * FROM cliente
ORDER BY idcliente DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_componente]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_componente]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_componente]
AS
SELECT * FROM componente
ORDER BY idcomponente DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_corte_caja]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_corte_caja]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_corte_caja]
AS
SELECT * FROM corte_caja
ORDER BY idcorte_caja DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_detalle_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_detalle_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_detalle_ingreso]
AS
SELECT * FROM detalle_ingreso
ORDER BY iddetalle_ingreso DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_detalle_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_detalle_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_detalle_venta]
AS
SELECT * FROM detalle_venta
ORDER BY iddetalle_venta DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_empleado]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_empleado]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROC [dbo].[spmostrar_empleado]
AS
SELECT * FROM empleado
ORDER BY idempleado DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_ingreso]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_ingreso]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_ingreso]
AS
SELECT * FROM ingreso
ORDER BY idingreso DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_inventario]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_inventario]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_inventario]
AS
SELECT * FROM inventario
ORDER BY idinventario DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_producto]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_producto]
AS
SELECT * FROM productos
ORDER BY idproducto DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_proveedor]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_proveedor]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROC [dbo].[spmostrar_proveedor]
AS
SELECT * FROM proveedor
ORDER BY idproveedor DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_retiro]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_retiro]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_retiro]
AS
SELECT * FROM retiro
ORDER BY idretiro DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_state]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_state]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimientos para la tabla 'state'


CREATE PROC [dbo].[spmostrar_state]
AS
SELECT * FROM state
ORDER BY idstate DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_sub_categoria]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_sub_categoria]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_sub_categoria]
AS
SELECT * FROM sub_categoria
ORDER BY idsub_categoria DESC
GO

-- %% [markdown]
-- # [dbo].[spmostrar_venta]

-- %%
/****** Object:  StoredProcedure [dbo].[spmostrar_venta]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spmostrar_venta]
AS
SELECT * FROM venta
ORDER BY idventa DESC
GO

-- %% [markdown]
-- # [dbo].[spstate_insertar_nuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[spstate_insertar_nuevo]    Script Date: 27/03/2024 01:13:35 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[spstate_insertar_nuevo]
    @idstate int output
AS
insert into dbo.[state] (idstate)
	values (@idstate)
GO

-- %% [markdown]
-- # [PDVKraken_2]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PDVKraken_2] SET  READ_WRITE 
GO
